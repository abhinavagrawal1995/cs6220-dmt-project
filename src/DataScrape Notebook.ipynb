# %% [markdown]
# This is the template for how we collected all the feature data we used.
# The process below was repeated for various slices of 10000 playlists, and a slice was used every time the requests broke down (from an authentification token timeout, being blocked for too many hits, an internet error, etc.)

# %%
# %%bash
# head 'mpd.v1/data/mpd.slice.20000-20999.json'
#
# # preview first few lines
# Out:
# {
#     "info": {
#         "generated_on": "2017-12-03 08:41:42.057563",
#         "slice": "20000-20999",
#         "version": "v1"
#     },
#     "playlists": [
#         {
#             "name": "Prelude",
#             "collaborative": "false",

# %%
import ijson

filename = "mpd.v1/data/mpd.slice.20000-20999.json"

# open file with current slice of 1000 playlists
with open(filename, 'r') as f:
    objects = ijson.items(f, 'playlists.item')
    columns = list(objects)

# %%
column_names = [col["tracks"] for col in columns]

# %%
# get track URI and names from playlists; we will use these as reference points when we hit the Spotify API
playlists = column_names
track_features_uri = []
track_features_name = []
for playlist in playlists:
    for tracks in playlist:
        track_features_uri.append(tracks["track_uri"])
        track_features_name.append(tracks["track_name"])

# %%
import pandas as pd
track_features = pd.DataFrame(track_features_name, columns=['track_name'])
track_features["ids"] = track_features_uri
track_features = track_features.drop_duplicates()
track_features.ids = track_features.ids.str.slice(14)
track_features = track_features.reset_index()
track_features.head()
# Out:
#    index                                         track_name  \
# 0      0                                   A Thousand Years
# 1      1  Can't Help Falling In Love - Recorded Live at ...
# 2      2                                             Ho Hey
# 3      3                                         Everything
# 4      4                                        She Is Love
#
#                       ids
# 0  4eYaDRhiL5iesFp2EuoODr
# 1  5GBWQszdw6PtAN0Negzut6
# 2  1jdNcAD8Ir58RlsdGjJJdx
# 3  4T6HLdP6OcAtqC6tGnQelG
# 4  1q74TesvRCIo5RvJM5B84F

# %%
# how many tracks in the current slice?
track_features.shape
# Out:
# (35247, 3)

# %%
# various arrays to store later dataframe's column data; we manually chose potentially relevant attributes

# from Spotify track object
album_id = [] 
album_name = [] 
album_release_date = [] 

track_artist_ids = [] 

track_id = [] 
track_duration_ms = [] 
track_explicit = [] 
track_name = [] 
track_popularity = [] 

# from Spotify audio features object
danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
audio_features_id = []

# from Spotify artist object
artist1_id = []
followers = []
artist_popularity = []
artist_genre1 = []
artist_genre2 = []
artist_genre3 = []

# from Spotify album object
album_label = []
album_popularity = []

# %%
import requests
i=0

for ids in track_features.ids:
    
    # FROM TRACK OBJECT
    track_features_endpoint = "https://api.spotify.com/v1/tracks/{}".format(ids)
    # the below authorization token must be periodically changed and manually requested from the Spotify API
    headers = {"Authorization":"Bearer BQCqe5naoZO73MxotOI1nxw9QgiYYkpwv148di3XSYyc8zEF2-lc_2DDWKxi383ZuNZVTSMECpa5Wp5OWyyiaXj_WUH_ZrlQyLLvwNiS-NYOtzr_u2wzkJMA3fZLY46KInkd8H9iRFWuAfAG2nl9rG02PyLtxRhpRIEIjNd1T-J_biHFN5gTfZZpKmXsS83tqoT0LYIQF9-LFVTuOTwbgvWcvVKnV7J0VmfdCd75Mwupgiq1ag--TKTeVkyvPD_NubDH46m_kC0XDe8c"}
    rep = requests.get(url=track_features_endpoint, headers=headers).json()
    
    album_id.append(rep['album']['id'])
    cur_album_id = album_id[i]
    
    album_name.append(rep["album"]["name"])
    album_release_date.append(rep["album"]["release_date"])
    
    track_artist_ids.append([artist['id'] for artist in rep['artists']]) #this is multiple but we're only doing 1st
    track_artist_id1 = track_artist_ids[i][0]
    
    track_id.append(rep['id'])
    track_duration_ms.append(rep["duration_ms"])
    track_explicit.append(rep["explicit"])
    track_name.append(rep["name"])
    track_popularity.append(rep["popularity"])
    
    # FROM ARTIST OBJECT
    artists_endpoint = "https://api.spotify.com/v1/artists/{}".format(track_artist_id1)
    rep = requests.get(url=artists_endpoint,headers=headers).json()
    artist1_id.append(rep['id'])
    followers.append(rep["followers"]["total"])
    artist_popularity.append(rep["popularity"])
    if len(rep['genres']) >= 1:
        artist_genre1.append(rep['genres'][0])
    else:
        artist_genre1.append(None)
    if len(rep['genres']) >= 2:
        artist_genre2.append(rep['genres'][1])
    else:
        artist_genre2.append(None)
    if len(rep['genres']) >= 3:
        artist_genre3.append(rep['genres'][2])
    else:
        artist_genre3.append(None)
    
    
    # FROM AUDIO FEATURES OBJECT
    audio_features_endpoint = "https://api.spotify.com/v1/audio-features/{}".format(ids)
    rep = requests.get(url=audio_features_endpoint, headers=headers).json()
    danceability.append(rep["danceability"])
    energy.append(rep["energy"])
    key.append(rep["key"])
    loudness.append(rep["loudness"])
    mode.append(rep["mode"])
    speechiness.append(rep["speechiness"])
    acousticness.append(rep["acousticness"])
    instrumentalness.append(rep["instrumentalness"])
    liveness.append(rep["liveness"])
    valence.append(rep["valence"])
    tempo.append(rep["tempo"])
    audio_features_id.append(rep['id'])
    
    # FROM ALBUM OBJECT
    albums_endpoint = "https://api.spotify.com/v1/albums/{}".format(cur_album_id)
    rep = requests.get(url=albums_endpoint, headers=headers).json()
    album_label.append(rep["label"])
    album_popularity.append(rep["popularity"])
    
    if i==10000:
        break
    # print all i's so we can figure out when the scraping broke down
    i = i + 1

# %%
# SPECIAL CELL: this is for when the scraping breaks down IN THE MIDDLE of the previous cell's running. You can see 
# on which object request the scraping broke, so append None to all lists after that breakdown

# this ensures that when we combine all the lists into one dataframe, it doesn't automatically drop columns with 
# no data (from the breakdown)


# tracks
album_id.append(None)
album_name.append(None)
album_release_date.append(None)

track_artist_ids.append(None)

track_id.append(None)
track_duration_ms.append(None)
track_explicit.append(None)
track_name.append(None)
track_popularity.append(None)

#artists 
artist1_id.append(None)
followers.append(None)
artist_popularity.append(None)
artist_genre1.append(None)
artist_genre2.append(None)
artist_genre3.append(None)

#audio features 
danceability.append(None)
energy.append(None)
key.append(None)
loudness.append(None)
mode.append(None)
speechiness.append(None)
acousticness.append(None)
instrumentalness.append(None)
liveness.append(None)
valence.append(None)
tempo.append(None)
audio_features_id.append(None)

#albums
album_label.append(None)
album_popularity.append(None)

# %%
# combine all lists into one df
track_records = pd.DataFrame(album_id, columns=['album_id'])

track_records["album_name"] = album_name
track_records["album_release_date"] = album_release_date

track_records["track_artist_ids"] = track_artist_ids

track_records['track_id'] = track_id
track_records["track_duration_ms"] = track_duration_ms
track_records["track_explicit"] = track_explicit
track_records["track_name"] = track_name
track_records["track_popularity"] = track_popularity


track_records["danceability"] = danceability
track_records["energy"] = energy
track_records["key"] = key
track_records["loudness"] = loudness
track_records["mode"] = mode
track_records["speechiness"] = speechiness
track_records["acousticness"] = acousticness
track_records["instrumentalness"] = instrumentalness
track_records["liveness"] = liveness
track_records["valence"] = valence
track_records["tempo"] = tempo
track_records["audio_features_id"] = audio_features_id

track_records['artist1_id'] = artist1_id
track_records['followers'] = followers
track_records['artist_popularity'] = artist_popularity
track_records['artist_genre1'] = artist_genre1
track_records['artist_genre2'] = artist_genre2
track_records['artist_genre3'] = artist_genre3

track_records['album_label'] = album_label
track_records['album_popularity'] = album_popularity

# %%
track_records.shape
# Out:
# (1989, 29)

# %%
track_records
# Out:
#                     album_id  \
# 0     1gIuyEXICtt24CEKrYSOw8
# 1     7o2VLivg95UduHjTMTIEIf
# 2     5h7fx8ILwOZ3I5yQ4eGBl7
# 3     3h4pyWRJIB9ZyRKXChbX22
# 4     6QJw1UxLAFYQfy8XirsXiW
# 5     6Pb3K1oPXdhsqFXtzKe3Z1
# 6     10HuTnFqkhym6gXmIDxBsm
# 7     39xrkt8RILtwa9DMyLkv32
# 8     5HHP1ctEzugQvbPCKJiWkc
# 9     1hyorM32T35U5HAxdh6glI
# 10    5fQ4tDLM2FfesO66R9nDF9
# 11    2zLZzOfiwQ4hnPCu2gVtKB
# 12    4CVzsnMQTcC5mfU4XNTTaI
# 13    5d9FNx7UMLgfiGQGXU19jh
# 14    2DhfVYIEdTZLLFJ3WKBApc
# 15    3NcGNYXKiHeygdXXL7czL1
# 16    3NPyAfTeu40LVzwvqQ6Rl7
# 17    2oAh7vprZx8iSqoyNxQASX
# 18    2G9UuU6wxAa4FoIv1rwHBo
# 19    1csBXckSWxkPEUXT4nSeP3
# 20    7Ghyo1U9g3ZILTT5Kn6DD1
# 21    4agEw6mF6zvlt42zdlT6VY
# 22    4uG8q3GPuWHQlRbswMIRS6
# 23    5yIiFmVkza1N3ddMtftxIZ
# 24    5msfCyqu8fJYqDDV6OrXTg
# 25    12DdKE2ScfqqnBEIXL9WM5
# 26    07fUjvOPfrD7pe5ACRsyVy
# 27    1hyorM32T35U5HAxdh6glI
# 28    2btXQFitnklvkPC0dAIvAx
# 29    7p82DTmb2pwKwzXBLlURT6
# ...                      ...
# 1959  0lUL92det7mZ4DaHYmiUEC
# 1960  5W98Ab4VvQEuFEE4TIe5fE
# 1961  1BFCyhRrtgOwgJq7AtWfBL
# 1962  5tBOCi2TekXZ1IbrmlBZO4
# 1963  3yWRq9Dd2UO5xyqxTjLDmp
# 1964  28ZKQMoNBB0etKXZ97G2SN
# 1965  41Tj1cy7HlmdSmaOO6f6Tl
# 1966  1BSzAkEW5ZE2QsBScQgoAb
# 1967  2jg7PvepCK9V7MyWM7pvzr
# 1969                    Waves (Robin Schulz Radio Edit)         2014-02-07
# 1970                    Fórmula Vol. 1 (Deluxe Edition)         2012-08-27
# 1971                                            Halcyon         2012-01-01
# 1972                                      It's About Us         2014-10-06
# 1973                                      head or heart         2014-03-27
# 1974                                I'm Falling for You         2013-02-11
# 1975                                     Gossip Columns         2017-10-13
# 1976                                    Joanne (Deluxe)         2016-10-21
# 1977                                    Joanne (Deluxe)         2016-10-21
# 1978                                                 25         2016-06-24
# 1979                                 Back from the Edge         2016-10-28
# 1980                                               Loud         2010-11-16
# 1981                                            Jealous         2014-11-21
# 1982                                          Rockferry               2008
# 1983                                          Rockferry               2008
# 1984                     Nobody But Me (Deluxe Version)         2016-10-21
# 1985                                                 25         2016-06-24
# 1986                                                VHS         2015-06-30
# 1987                                         The Script               2008
# 1988             Keeps Gettin' Better: A Decade Of Hits               1999
#
#                                       track_artist_ids  \
# 0                             [0jW6R8CVyVohuUJVcuweDI]
# 1                             [2vm8GdHyrJh2O2MfbQFYG0]
# 2                             [16oZKvXb6WkQlVAjwo2Wbg]
# 3                             [1GxkXlMwML1oSg5eLPiAz3]
# 4                             [2PCUhxD40qlMqsKHjTZD2e]
# 5                             [4dpARuHxo51G3z768sgnrY]
# 6                             [4LEiUm1SRbFMgfqnQTwUbQ]
# 7                             [7giUHu5pv6YTZgSkxxCcgh]
# 8                             [3hozsZ9hqNq7CoBGYNlFTz]
# 9                             [5tI0Vj2FhioY8AKtEqu9d3]
# 10                            [0g7gHEXKEHU4snTwOZSxNO]
# 11    [7crPfGd2k81ekOoSqQKWWz, 5dbuFbrHa1SJlQhQX9OUJ2]
# 12                            [3pTE9iaJTkWns3mxpNQlJV]
# 13                            [5gInJ5P5gQnOKPM3SUEVFt]
# 14                            [267VY6GX5LyU5c9M85ECZQ]
# 15                            [5gInJ5P5gQnOKPM3SUEVFt]
# 16                            [56ZTgzPBDge0OvCGgMO3OY]
# 17                            [3UpIbyXfGzmHG6TMH4dJEk]
# 18                            [3TBfn8PtXr42OrTPaoC3E8]
# 19                            [6eO95BjZhrWHREMfwC4vVN]
# 20                            [0aWSylARSZCDo7vTDgvKbb]
# 21                            [0aWSylARSZCDo7vTDgvKbb]
# 22                            [7oPftvlwr6VrsViSDV7fJY]
# 23                            [4Cedjq5BQL3MhapRvDpFED]
# 24                            [5o206eFLx38glA2bb4zqIU]
# 25                            [62ZE05EcDkspUxRw1u2ger]
# 26                            [0aWSylARSZCDo7vTDgvKbb]
# 27                            [5tI0Vj2FhioY8AKtEqu9d3]
# 28                            [1aOp1lgpcwRxADf1jHvXhu]
# 29                            [03ilIKH0i08IxmjKcn63ne]
# ...                                                ...
# 1959                          [1z7b1Pr1rSlvWRzsW3HOrS]
# 1960  [6JL8zeS1NmiOftqZTRgdTz, 5y2Xq6xcjJb2jVM54GHK3t]
# 1961                          [3700G3mzTkuxc5U7hdE9CV]
# 1962                          [2jku7tDXc6XoB6MO2hFuqg]
# 1963  [6TIYQ3jFPwQSRmorSezPxX, 4nDoRrQiYLoBzwC5BhVJzF]
# 16                                            Real Love                21
# 17                                          Ghost World                17
# 18                             Hounds of Love - new mix                51
# 19                                        Lust for Life                40
# 20                                          Dirty Hands                 6
# 21                                           Turn Me On                26
# 22                                   When I Come Around                71
# 23                                          Lion's Jaws                27
# 24                          We Are Nowhere And It's Now                47
# 25                                          Tongue Tied                 8
# 26                                The Sum Of Every Part                 5
# 27                                          Mother Mary                40
# 28                                            I Just Do                34
# 29                                        I Found A Way                51
# ...                                                 ...               ...
# 1959                                      Losin Control                77
# 1960                            Like I'm Gonna Lose You                78
# 1961                                      Dans Tes Yeux                39
# 1962                                             Say It                70
# 1963                   Bad Things (with Camila Cabello)                71
# 1964                                          Shameless                51
# 1965                                       I Choose You                56
# 1966                             If I Ever Fall In Love                55
# 1967                         Can't Help Falling in Love                73
# 1968                                     Doing It Wrong                65
# 1969                    Waves - Robin Schulz Radio Edit                77
# 1970                                            Promise                67
# 1971                                         Explosions                36
# 1972                                        Back to You                49
# 1973                                          the words                53
# 1974                                I'm Falling for You                42
# 1975                                           You & Me                64
# 1976                                    Million Reasons                62
# 1977                                   Perfect Illusion                51
# 1978                             Water Under the Bridge                70
# 1979                               Say You Won't Let Go                82
# 1980             Love The Way You Lie (Part II) - Pt. 2                63
# 1981                                            Jealous                76
# 1982                                              Mercy                66
# 1983                                     Stepping Stone                49
# 1984       On an Evening in Roma (Sott'er Celo de Roma)                54
# 1985                   Send My Love (To Your New Lover)                72
# 1986                                           Unsteady                75
# 1987                         The Man Who Can't Be Moved                46
# 1988                                            Fighter                52
#
#       danceability        ...           tempo       audio_features_id  \
# 0            0.230        ...         157.084  4eYaDRhiL5iesFp2EuoODr
# 1            0.244        ...          72.868  5GBWQszdw6PtAN0Negzut6
# 2            0.685        ...          79.991  1jdNcAD8Ir58RlsdGjJJdx
# 3            0.686        ...         123.125  4T6HLdP6OcAtqC6tGnQelG
# 4            0.629        ...         134.297  1q74TesvRCIo5RvJM5B84F
# 5            0.325        ...          72.416  7rPLZ8Krm6CZIbraFUlnWZ
# 6            0.591        ...          76.396  3ZMv9EzGoteNi5Qnx0KpEO
# 7            0.542        ...         111.665  7w5cxTEzp1rfV3KCy0Bd5N
# 8            0.524        ...          81.898  27VCODQk90XyqJB1FdwqyT
# 9            0.344        ...         135.116  5S1jZIl6Hviwdr7KFTG4kz
# 10           0.291        ...         131.629  44RC9eJQrOBYronf3UrsoO
# 11           0.553        ...          76.074  2npStoMbQxG1LcIeF4PZrj
# 12           0.246        ...         128.117  4rII58jraqoGYro5yjXQlM
# 13           0.400        ...         115.149  6nGQQsrsi1R7rbHWhqdZcf
# 14           0.287        ...         131.482  1Yx2hLDlw3q0j1zzamKjSd
# 15           0.382        ...         131.365  2VnI7kepsKFFh3WUI7wRAc
# 16           0.607        ...          99.535  2IhQf6LYr21OMxBowf76QE
# 17           0.483        ...         100.282  1dvSBbiXNGJcvE3fb3XcOy
# 18           0.360        ...         168.214  7mAF2MJdbNT75VrVcgwT6F
# 19           0.279        ...          77.370  5FH0pGKry3eL56IHjEgjPm
# 20           0.645        ...         107.426  3c6ZmMHskspjQ6TKvW5t1X
# 21           0.440        ...         145.039  0quMYDxD03EailjlR7x1XB
# 22           0.531        ...          97.546  1Dr1fXbc2IxaK1Mu8P8Khz
# 23           0.336        ...         167.996  4ny4sqrQmzhwHk7IHIVmL1
# 24           0.413        ...         147.076  6QSmeY9pNWnE0fAUrXmYC7
# 25           0.307        ...         173.640  1CwDpUvvqJ2zD3Hh6m69NF
# 26           0.734        ...         147.132  10d09tKIdxkjaSaiNXFM3S
# 27           0.413        ...         105.460  5KcgqKXySkWnh4cZ4vG2A8
# 28           0.550        ...         106.032  6eVq1guYib8O13Hhal0r2Y
# 29           0.531        ...         130.048  1rS3J4u1G8f6hbmTosa8Nf
# ...            ...        ...             ...                     ...
# 1959         0.759        ...          96.992  4cxMGhkinTocPSVVKWIw0d
# 1960         0.630        ...         108.038  2YlZnw2ikdb837oKMKjBkW
# 1961         0.504        ...         181.781  1jO3MaCjrRQusiqkZQPA9h
# 1962         0.546        ...         107.331  2Gyc6e2cLxA5hoX1NOvYnU
# 1963         0.697        ...         137.853  1PSBzsahR2AKwLJgx8ehBj
# 1964         0.602        ...         100.021  66UVpCZ5aH3VV3Ic3PBUrP
# 1965         0.673        ...          90.107  1KKpOFUTS8B9pD5x3PevoX
# 1966         0.635        ...         127.922  0uOPGU4CbYxzFxn6T7sblW
# 1967         0.410        ...         137.970  6yIHGmQLJxWAUZ1ZkENemN
# 1968         0.397        ...         101.275  4eSGSqP2TZvvX0kadZZttM
# 1969         0.829        ...         119.993  5Sf3GyLEAzJXxZ5mbCPXTu
# 1970         0.764        ...         132.995  0jr6tT2vc4cIFPHb6wufG3
# 1971         0.299        ...          95.929  2AMEPKeicePOewTaGLYqec
# 1972         0.363        ...         133.869  7JYcQU1Dv1Rabv3AQyynWD
# 1973         0.505        ...          77.023  0zxG0MKqXBEbwU09H7gEIs
# 1974         0.528        ...         136.224  7sdT7TgonQCKsdjhShEdYO
# 1975         0.696        ...          85.091  7yCqehT9dKACTFy7YugP0J
# 1976         0.668        ...         129.889  50PWlIBU7PlGGwzgN8TiFJ
# 1977         0.616        ...         124.988  5ou59ERA2f7ffyAxAcZyVz
# 1978         0.596        ...          94.982  4vb4mFvYsr2h6enhjJsq9Y
# 1979         0.358        ...          85.043  5uCax9HTNlzGybIStD3vDh
# 1980         0.473        ...         166.385  6M6lsQB4OhqL41eld29PeC
# 1981         0.435        ...         128.532  4L2K7JKseFCBoHMZEAszW0
# 1982         0.793        ...         129.912  1zusIxNqJu8i4g6P6hJ2Qa
# 1983         0.694        ...          97.985  3g9nxeJPQM4CxhHt1iNlB4
# 1984         0.431        ...         137.021  4JEC2RIrXV1owJNVKanIAT
# 1985         0.690        ...         164.023  4BHzQ9C00ceJxfG16AlNWb
# 1986         0.389        ...         117.055  7lGKEWMXVWWTt3X71Bv44I
# 1987         0.609        ...          99.955  67EY6aDoIx8czEPS6a2AaI
# 1988         0.432        ...         188.858  5jaOa7ybiQjBdhoouGuNjH
#
#                   artist1_id  followers  artist_popularity  \
# 0     0jW6R8CVyVohuUJVcuweDI     784409                 65
# 1     2vm8GdHyrJh2O2MfbQFYG0     505291                 61
# 2     16oZKvXb6WkQlVAjwo2Wbg    2619293                 74
# 3     1GxkXlMwML1oSg5eLPiAz3    2627273                 72
# 4     2PCUhxD40qlMqsKHjTZD2e     339532                 58
# 5     4dpARuHxo51G3z768sgnrY   10592482                 81
# 6     4LEiUm1SRbFMgfqnQTwUbQ    2051334                 71
# 7     7giUHu5pv6YTZgSkxxCcgh     720594                 65
# 8     3hozsZ9hqNq7CoBGYNlFTz     288245                 55
# 9     5tI0Vj2FhioY8AKtEqu9d3      16135                 31
# 10    0g7gHEXKEHU4snTwOZSxNO       1882                 22
# 11    7crPfGd2k81ekOoSqQKWWz     392134                 62
# 12    3pTE9iaJTkWns3mxpNQlJV     552751                 59
# 13    5gInJ5P5gQnOKPM3SUEVFt     100323                 45
# 14    267VY6GX5LyU5c9M85ECZQ     203260                 52
# 15    5gInJ5P5gQnOKPM3SUEVFt     100323                 45
# 16    56ZTgzPBDge0OvCGgMO3OY     659417                 66
# 17    3UpIbyXfGzmHG6TMH4dJEk      96448                 48
# 18    3TBfn8PtXr42OrTPaoC3E8      44288                 42
# 19    6eO95BjZhrWHREMfwC4vVN      79268                 41
# 20    0aWSylARSZCDo7vTDgvKbb      10021                 26
# 21    0aWSylARSZCDo7vTDgvKbb      10021                 26
# 22    7oPftvlwr6VrsViSDV7fJY    7052962                 78
# 23    4Cedjq5BQL3MhapRvDpFED     110980                 54
# 24    5o206eFLx38glA2bb4zqIU     318654                 58
# 25    62ZE05EcDkspUxRw1u2ger       2604                 17
# 26    0aWSylARSZCDo7vTDgvKbb      10021                 26
# 27    5tI0Vj2FhioY8AKtEqu9d3      16135                 31
# 28    1aOp1lgpcwRxADf1jHvXhu      20528                 40
# 29    03ilIKH0i08IxmjKcn63ne     172414                 49
# ...                      ...        ...                ...
# 1959  1z7b1Pr1rSlvWRzsW3HOrS    1515680                 79
# 1960  6JL8zeS1NmiOftqZTRgdTz    6027065                 76
# 1961  3700G3mzTkuxc5U7hdE9CV      10186                 33
# 1962  2jku7tDXc6XoB6MO2hFuqg    1523893                 79
# 1963  6TIYQ3jFPwQSRmorSezPxX    1116489                 74
# 1964  1Xyo4u8uXC1ZmMpatF05PJ   11713366                 87
# 1965  20s0P9QLxGqKuCsGwFsp7w    1058997                 66
# 1966  72y3ZI95ctkQC2O4mjBaU3     236642                 46
# 1967  5cKlE8f6b26h61Ml7m052Q     143811                 60
# 1968  3TVXtAsR1Inumwj472S9r4   24467846                100
# 1969  33W1pnW9zScZtYTnAoWnOT     249714                 68
# 1970  5lwmRuXgjX8xIwlnauTZIP    5503631                 79
# 1971  0X2BH1fck6amBIoJhDVmmJ    5097882                 76
# 1972  58MLl9nC29IXbE4nEtuoP2     489225                 66
# 1973  7H55rcKCfwqkyDFH9wpKM6    1438780                 71
# 1974  2iTiSaR023IikZDaOfEIRR      54549                 46
# 1975  3tQx1LPXbsYjE9VwN1Peaa     164943                 69
# 1976  1HY2Jd0NmPuamShAr6KMms    5369967                 78
# 1977  1HY2Jd0NmPuamShAr6KMms    5369967                 78
# 1978  4dpARuHxo51G3z768sgnrY   10593234                 81
# 1979  4IWBUUAFIplrNtaOHcJPRM    2334182                 78
# 1980  5pKCCKE2ajJHZ9KAiaK11H   25861503                 87
# 1981  2feDdbD5araYcm6JhFHHw7     629343                 76
# 1982  37NqXwtb6nIEqRt4EJSoIO     481005                 57
# 1983  37NqXwtb6nIEqRt4EJSoIO     481005                 57
# 1984  1GxkXlMwML1oSg5eLPiAz3    2627319                 72
# 1985  4dpARuHxo51G3z768sgnrY   10593239                 81
# 1986  3NPpFNZtSTHheNBaWC82rB    1112412                 74
# 1987  3AQRLZ9PuTAozP28Skbq8V    3879625                 74
# 1988  1l7ZsJRRS8wlW3WfJfPfNS    3365610                 77
#
#                     artist_genre1       artist_genre2  \
# 0                         bow pop            classify
# 1                    acoustic pop            ectofolk
# 2                        folk-pop          indie folk
# 3                 adult standards        canadian pop
# 4                    acoustic pop       indiecoustica
# 5                             pop                None
# 6                     chamber pop            folk-pop
# 7                     chamber pop            folk-pop
# 8                alternative rock       chicago indie
# 9                            None                None
# 10                           None                None
# 11                     album rock      heartland rock
# 12              alternative dance  british indie rock
# 13                    chamber pop            folk-pop
# 14                alternative pop    alternative rock
# 15                    chamber pop            folk-pop
# 16                        art pop         chamber pop
# 17                           folk            folk-pop
# 18             british indie rock          dance-punk
# 19                        art pop      bay area indie
# 20    australian alternative rock                None
# 21    australian alternative rock                None
# 22                 permanent wave            pop punk
# 23            alternative country           anti-folk
# 24                      anti-folk         chamber pop
# 25                      candy pop      power-pop punk
# 26    australian alternative rock                None
# 27                           None                None
# 28                         dreamo         modern rock
# 29                  post-teen pop                None
# ...                           ...                 ...
# 1959                      hip hop                 pop
# 1960                    dance pop             hip pop
# 1961              french folk pop       french reggae
# 1962             canadian hip hop             hip hop
# 1963                      hip hop             pop rap
# 1964                 canadian pop                 pop
# 1965                    dance pop             hip pop
# 1966                     boy band             hip pop
# 1967                         None                None
# 1968             canadian hip hop        canadian pop
# 1969               tropical house                None
# 1970                      bachata               latin
# 1971                    dance pop                 edm
# 1972                    dance pop          neo mellow
# 1973                    dance pop          neo mellow
# 1974                  channel pop           viral pop
# 1975                    dance pop           indie r&b
# 1976                    dance pop                 pop
# 1977                    dance pop                 pop
# 1978                          pop                None
# 1979                    dance pop          neo mellow
# 1980                    dance pop                 pop
# 1981                    dance pop                 pop
# 1982                    dance pop            neo soul
# 1983                    dance pop            neo soul
# 1984              adult standards        canadian pop
# 1985                          pop                None
# 1986      modern alternative rock         modern rock
# 1987                  celtic rock          neo mellow
# 1988                    dance pop                 pop
#
#                   artist_genre3                          album_label  \
# 0                          None            Portrait/Sony Masterworks
# 1                      folk-pop                     Cabin 24 Records
# 2                     indie pop                Universal Music Group
# 3                        lounge                          143/Reprise
# 4                    neo mellow                Universal Music Group
# 5                          None               XL Recordings/Columbia
# 6                    indie folk                           Jagjaguwar
# 7                    indie folk                      Vagrant Records
# 8                         comic                      Capitol Records
# 9                          None                  Jingle Town Records
# 10                         None                           ABKCO (US)
# 11                  mellow gold                       Rhino Atlantic
# 12                   indie folk                Universal Music Group
# 13                    indie pop                      Elefant Records
# 14                   blues-rock                                WM UK
# 15                    indie pop                      Elefant Records
# 16                    chillwave                           Mistletone
# 17                    indie pop                     SuperEgo Records
# 18                  garage rock                       Rhino Atlantic
# 19                    chillwave         Fantasy Trashcan (Turnstile)
# 20                         None       Death Valley Records and Tapes
# 21                         None  Universal Music Australia Pty. Ltd.
# 22                         punk                              Reprise
# 23                      art pop                         Anti/Epitaph
# 24                     folk-pop                         Saddle Creek
# 25                         None                 Kind Of Like Records
# 26                         None  Universal Music Australia Pty. Ltd.
# 27                         None                  Jingle Town Records
# 28    progressive post-hardcore                 Equal Vision Records
# 29                         None                         Nick Records
# ...                         ...                                  ...
# 1959                        rap                             Columbia
# 1960                        pop                                 Epic
# 1961                french rock                    Parlophone France
# 1962                  indie r&b                   Benny Blanco Major
# 1963                        rap                   Bad Boy Records PS
# 1964                        rap                Universal Music Group
# 1965                        pop                            J Records
# 1966             new jack swing                           Interscope
# 1967                       None                          Ole Red Dot
# 1968                    hip hop                   Drake (Cash Money)
# 1969                       None                 Left Lane Recordings
# 1970                   tropical                     Sony Music Latin
# 1971                 electropop                      Polydor Records
# 1972                        pop          Syco Music/Columbia Records
# 1973                        pop                     Atlantic Records
# 1974                       None                          Chester See
# 1975                        pop        Republic Records/Gee Roberson
# 1976              post-teen pop                Universal Music Group
# 1977              post-teen pop                Universal Music Group
# 1978                       None               XL Recordings/Columbia
# 1979                        pop                             Columbia
# 1980                        r&b                Universal Music Group
# 1981                    pop rap                           Syco Music
# 1982                        pop                      Polydor Records
# 1983                        pop                      Polydor Records
# 1984                     lounge                              Reprise
# 1985                       None               XL Recordings/Columbia
# 1986                        pop          Kid Ina Korner / Interscope
# 1987                        pop                           Phonogenic
# 1988              post-teen pop                    RCA Records Label
#
#       album_popularity
# 0                   43
# 1                   45
# 2                   66
# 3                   66
# 4                   49
# 5                   50
# 6                   45
# 7                   67
# 8                   32
# 9                   39
# 10                  31
# 11                  54
# 12                  43
# 13                  34
# 14                   1
# 15                  44
# 16                  35
# 17                  30
# 18                  45
# 19                  37
# 20                  15
# 21                  21
# 22                  75
# 23                  47
# 24                  64
# 25                  12
# 26                  17
# 27                  39
# 28                  44
# 29                  44
# ...                ...
# 1959                80
# 1960                75
# 1961                37
# 1962                69
# 1963                69
# 1964                67
# 1965                53
# 1966                53
# 1967                65
# 1968                79
# 1969                69
# 1970                73
# 1971                52
# 1972                72
# 1973                59
# 1974                34
# 1975                67
# 1976                59
# 1977                59
# 1978                76
# 1979                79
# 1980                73
# 1981                68
# 1982                62
# 1983                62
# 1984                63
# 1985                76
# 1986                73
# 1987                45
# 1988                56
#
# [1989 rows x 29 columns]

# %%
# export that data to a csv, which we will merge with all other csvs in Excel
track_records.to_csv("20000-20999,1988.csv", sep=',')
